# %% [markdown]
# <a href="https://colab.research.google.com/github/Arimateia00/atividade-phyton/blob/main/atividade01_phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 01 - Introdução ao Phyton

# %%
print ("Minha primeira atividade no Google Colab")
print ("Aprendendo phyton e GitHub")
# Out:
# Minha primeira atividade no Google Colab
# Aprendendo phyton e GitHub

# %%
Disciplina = input ("Digite o nome da disciplina: ")
Conteudo = input ("Digite o conteúdo estudado: ")
Numero = input ("Digite o numero da atividade: ")
# Out:
# Digite o nome da disciplina: ALP
# Digite o conteúdo estudado: Phyton
# Digite o numero da atividade: 01

# %%
print ("Aprendendo versionamneto de projetos! ")
# Out:
# Aprendendo versionamneto de projetos!
